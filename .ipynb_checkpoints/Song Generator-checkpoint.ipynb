# %%
import urllib.request as urllib2
from bs4 import BeautifulSoup
import pandas as pd
import re
from unidecode import unidecode
import csv
from datetime import datetime

# %%
all_pages=[]
link_page = urllib2.urlopen('http://www.metrolyrics.com/taylor-swift-lyrics.html')
soup = BeautifulSoup(link_page, 'html.parser')
pages = soup.find_all('span', attrs={'class': 'pages'})
for x in pages[0].find_all('a'):
    all_pages.append(x['href'])

# %%
for link in all_pages:
    scrap_songs(link)
# Out:
# scrapping
# ...Ready For It? Lyrics
#
# scrapping
# 22 Lyrics
#
# scrapping
# A Chance Lyrics
#
# scrapping
# A Love Story Lyrics
#
# scrapping
# A Perfectly Good Heart Lyrics
#
# scrapping
# A Place In This World Lyrics
#
# scrapping
# All Too Well Lyrics
#
# scrapping
# All You Had To Do Was Stay Lyrics
#
# scrapping
# Am I Ready For Love? Lyrics
#
# scrapping
# American Boy Lyrics
#
# scrapping
# American Girl Lyrics
#
# scrapping
# Baby Don't Break My Heart Slow Lyrics
#
# scrapping
# Back To December Lyrics
#
# scrapping
# Bad Blood Lyrics
#
# scrapping
# Bad Blood (Remix) Lyrics
#
# scrapping
# Beautiful Eyes Lyrics
#
# scrapping
# Beautiful Eyes Lyrics
#
# scrapping
# Begin Again Lyrics
#
# scrapping
# Being With My Baby Lyrics
#
# scrapping
# Belong With Me Lyrics
#
# scrapping
# Better Off Lyrics
#
# scrapping
# Better Than Revenge Lyrics
#
# scrapping
# Blank Space Lyrics
#
# scrapping
# Blank Spaces Lyrics
#
# scrapping
# Breathe Lyrics
#
# scrapping
# Breathless Lyrics
#
# scrapping
# Brought Up That Way Lyrics
#
# scrapping
# Change Lyrics
#
# scrapping
# Christmas Must Be Something More Lyrics
#
# scrapping
# Christmases When You Were Mine Lyrics
#
# scrapping
# Clean Lyrics
#
# scrapping
# Cold As You Lyrics
#
# scrapping
# Come Back... Be Here Lyrics
#
# scrapping
# Come In With The Rain Lyrics
#
# scrapping
# Crazier Lyrics
#
# scrapping
# Dark Blue Tennessee Lyrics
#
# scrapping
# Dear John Lyrics
#
# scrapping
# Delicate Lyrics
#
# scrapping
# Didn't They Lyrics
#
# scrapping
# Don't Blame Me Lyrics
#
# scrapping
# Drops Of Jupiter Lyrics
#
# scrapping
# Enchanted Lyrics
#
# scrapping
# End Game Lyrics
#
# scrapping
# Everything Has Changed Lyrics
#
# scrapping
# Everything Is Changed Lyrics
#
# scrapping
# Eyes Open Lyrics
#
# scrapping
# Fearless Lyrics
#
# scrapping
# Fifteen Lyrics
#
# scrapping
# Forever & Always Lyrics
#
# scrapping
# Forever & Always Lyrics
#
# scrapping
# Forever And Always Lyrics
#
# scrapping
# Girl At Home Lyrics
#
# scrapping
# Haunted Lyrics
#
# scrapping
# Hey Stephen Lyrics
#
# scrapping
# Holy Ground Lyrics
#
# scrapping
# Hopelessly Devoted To You Lyrics
#
# scrapping
# How You Get The Girl Lyrics
#
# scrapping
# I Almost Do Lyrics
#
# scrapping
# I Did Something Bad Lyrics
#
# scrapping
# I Don't Wanna Live Forever Lyrics
#
# scrapping
# I Heart ? Lyrics
#
# scrapping
# I Heart Question Mark Lyrics
#
# scrapping
# I Knew You Were Trouble Lyrics
#
# scrapping
# I Knew You Were Trouble (Remix) Lyrics
#
# scrapping
# I Know Places Lyrics
#
# scrapping
# I Wish You Would Lyrics
#
# scrapping
# I'd Lie Lyrics
#
# scrapping
# I'm Only Me When I'm With You Lyrics
#
# scrapping
# If This Was A Movie Lyrics
#
# scrapping
# Innocent Lyrics
#
# scrapping
# Invisible Lyrics
#
# scrapping
# Jump Then Fall Lyrics
#
# scrapping
# Last Christmas Lyrics
#
# scrapping
# Last Kiss Lyrics
#
# scrapping
# Long Live Lyrics
#
# scrapping
# Look What You Made Me Do Lyrics
#
# scrapping
# Love Song Lyrics
#
# scrapping
# Love Story Lyrics
#
# scrapping
# Lucky You Lyrics
#
# scrapping
# Made Up You Lyrics
#
# scrapping
# Mary's Song (Oh My My My) Lyrics
#
# scrapping
# Me Lyrics
#
# scrapping
# Mean Lyrics
#
# scrapping
# Mine Lyrics
#
# scrapping
# Monologue Song Lyrics
#
# scrapping
# Never Grow Up Lyrics
#
# scrapping
# Nevermind Lyrics
#
# scrapping
# New Romance Lyrics
#
# scrapping
# New Romantics Lyrics
#
# scrapping
# New Year's Day Lyrics
#
# scrapping
# One Way Ticket Lyrics
#
# scrapping
# Only Me When I'm With You Lyrics
#
# scrapping
# Our Last Night Lyrics
#
# scrapping
# Our Song Lyrics
#
# scrapping
# Ours Lyrics
#
# scrapping
# Out of the Woods Lyrics
#
# scrapping
# Permanent Marker Lyrics
#
# scrapping
# Picture To Burn Lyrics
#
# scrapping
# Picture To Buurn Lyrics
#
# scrapping
# Red Lyrics
#
# scrapping
# Ride Of Our Lives Lyrics
#
# scrapping
# Riptide Lyrics
#
# scrapping
# Ronan Lyrics
#
# scrapping
# Run Lyrics
#
# scrapping
# Sad Beautiful Tragic Lyrics
#
# scrapping
# Safe And Sound Lyrics
#
# scrapping
# Santa Baby Lyrics
#
# scrapping
# September Lyrics
#
# scrapping
# Shake It Off Lyrics
#
# scrapping
# Should Have Said No Lyrics
#
# scrapping
# Should've Said No Lyrics
#
# scrapping
# Silent Night Lyrics
#
# scrapping
# Sparks Lyrics
#
# scrapping
# Sparks Fly Lyrics
#
# scrapping
# Speak Now Lyrics
#
# scrapping
# Starlight Lyrics
#
# scrapping
# State Of Grace Lyrics
#
# scrapping
# Stay Beautiful Lyrics
#
# scrapping
# Stay Stay Stay Lyrics
#
# scrapping
# Style Lyrics
#
# scrapping
# Superman Lyrics
#
# scrapping
# Superstar Lyrics
#
# scrapping
# Sweeter Than Fiction Lyrics
#
# scrapping
# Teardrops Of My Guitar Lyrics
#
# scrapping
# Teardrops On My Guitar Lyrics
#
# scrapping
# Tell Me Why Lyrics
#
# scrapping
# That's The Way I Loved You Lyrics
#
# scrapping
# That's When Lyrics
#
# scrapping
# The Best Day Lyrics
#
# scrapping
# The Last Time Lyrics
#
# scrapping
# The Lucky One Lyrics
#
# scrapping
# The Moment I Knew Lyrics
#
# scrapping
# The Other Side Of The Door Lyrics
#
# scrapping
# The Outside Lyrics
#
# scrapping
# The Story Of Us Lyrics
#
# scrapping
# The Way I Loved You Lyrics
#
# scrapping
# There's Your Trouble Lyrics
#
# scrapping
# This Love Lyrics
#
# scrapping
# Tied Together With A Smile Lyrics
#
# scrapping
# Tim McGraw Lyrics
#
# scrapping
# Today Was A Fairytale Lyrics
#
# scrapping
# Tonight Is Our Last Night Lyrics
#
# scrapping
# Treacherous Lyrics
#
# scrapping
# Under My Head Lyrics
#
# scrapping
# Untouchable Lyrics
#
# scrapping
# Way I Loved U Lyrics
#
# scrapping
# We Are Never Ever Ever Getting Back Together Lyrics
#
# scrapping
# We Are Never Ever Getting Back Togethe Lyrics
#
# scrapping
# We Are Never Ever Getting Back Together Lyrics
#
# scrapping
# Welcome To New York Lyrics
#
# scrapping
# What To Wear Lyrics
#
# scrapping
# White Christmas Lyrics
#
# scrapping
# White Horse Lyrics
#
# scrapping
# Wildest Dreams Lyrics
#
# scrapping
# Wonderland Lyrics
#
# scrapping
# You All Over Me Lyrics
#
# scrapping
# You Are In Love Lyrics
#
# scrapping
# You Belong To Me Lyrics
#
# scrapping
# You Belong With Me Lyrics
#
# scrapping
# You Got It All Wrong Lyrics
#
# scrapping
# You R In Love Lyrics
#
# scrapping
# You're Not Sorry Lyrics
#
# scrapping
# You're Still Innocent Lyrics
#
# scrapping
# Your Anything Lyrics
#
# scrapping
# Your Face Lyrics
#
# scrapping
# Your Not Sorry Lyrics
#
# scrapping
# You're Still An Innocent Lyrics

# %%
def scrap_songs(link):
    
    page= link
    url_page = urllib2.urlopen(page)
    soup = BeautifulSoup(url_page, 'html.parser')
    table_body=soup.find('tbody')
    rows = table_body.find_all('tr')
    names=[]
    for row in rows:    
        matter=row.find_all('a', attrs={'class': 'title hasvidtable'})
        for a in matter:
            Name=a.string
            Name = re.sub(r"\[.*\]\n", "", unidecode(Name))
            Link=a['href']
            
            link_page = urllib2.urlopen(Link)
            soup = BeautifulSoup(link_page, 'html.parser')
            verses = soup.find_all('p', attrs={'class': 'verse'})
            lyrics=''
            for verse in verses:
                text=verse.text.strip()
                text = re.sub(r"\[.*\]\n", "", unidecode(text))
                lyrics=lyrics+' '+text.replace('\n',', ')
        
            print('scrapping'+ Name )
        
            with open('taylor_swift.csv', 'a') as csv_file:
             writer = csv.writer(csv_file)
             writer.writerow([Name, Link, lyrics])

# %%
data=pd.read_csv('ed_sheeran.csv',names = ["Song_Name", "Link", "Lyrics"])

# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop, Adam
from keras.utils.data_utils import get_file
import numpy as np
import pandas as pd
import random
import sys
import io
import re
from unidecode import unidecode

# %%
data=pd.read_csv('ed_sheeran.csv',names = ["Song_Name", "Link", "Lyrics"])
data
# Out:
#                                              Song_Name  \
# 0                      \nShe Looks So Perfect Lyrics\n
# 1                              \nShape of You Lyrics\n
# 2                                   \nPerfect Lyrics\n
# 3                                \nPhotograph Lyrics\n
# 4                         \nThinking Out Loud Lyrics\n
# 5                                   \nHappier Lyrics\n
# 6                                    \nA Team Lyrics\n
# 4     When your legs don't work like they used to b...
# 5     Walking down 29th and park, I saw you in anot...
# 6     White lips, pale face, Breathing in snowflake...
# 7     Oh, misty eye of the mountain below, Keep car...
# 8     I took the supermarket flowers from the windo...
# 9     When I was six years old, I broke my leg, I w...
# 10    Give me love like her, 'Cause lately I've bee...
# 11    I found a love, For me, Oh darling, just dive...
# 12    La, la, la, la I met this girl late last year...
# 13    It's just another night, And I'm staring at t...
# 14    I found a love for me, Oh darling, just dive ...
# 15    Settle down with me, Cover me up, Cuddle me i...
# 16    Oh, maybe I came on too strong, Maybe I waite...
# 17    Now I'm in town, break it down, thinking of m...
# 18    I'm gonna pick up the pieces, And build a Leg...
# 19    You look so wonderful in your dress, I love y...
# 20    You are the one, girl, And you know that it's...
# 21    She played the fiddle in an Irish band, But s...
# 22    When the sins of my father, Weigh down in my ...
# 23    It's late in the evening, Glass on the side, ...
# 24    I'm not a rapper I'm a singer with a flow, I'...
# 25    We're not, No we're not friends, Nor have we ...
# 26    Tell me that you'd turn down the man, Who ask...
# 27    Things were all good yesterday, And then the ...
# 28    You're just a small bump unborn, In four mont...
# 29    Ain't got a soapbox I can stand upon, But God...
# ..                                                 ...
# 150   Filled up with doubt, I have to move home, Bu...
# 151   You look so wonderful in your dress, I love y...
# 152   She's reinventing loving me, When we're resem...
# 153   Take me with you I do declare, I love you dea...
# 154   You're not her, Though I try to see you diffe...
# 155   I took the supermarket flowers from the windo...
# 156   I woke up early looking out my window, At the...
# 157   I'm not a rapper I'm a singer with a flow, I'...
# 158                                                NaN
# 159   You look so wonderful in your dress, I love y...
# 160   This city never sleeps, I hear the people wal...
# 161   Now I don't wanna hate you, Just wish you'd n...
# 162   Pass me a drink, You say it's gonna take a wh...
# 163   When your legs don't work like they used to b...
# 164   When your legs don't work like they used to b...
# 165   This is the start of something beautiful, Thi...
# 166   Waking up, Midnight November, And you're stil...
# 167   I found your hair band on my bedroom floor, T...
# 168   Made of clay, Shoot me down, I'll ricochet to...
# 169   I should ink my skin, With your name, And tak...
# 170   Well I once heard a story about a run-down ho...
# 171   Oooh ooh ooh, Ooooh oooh oooh ooh Oooh ooh oo...
# 172   Ain't got a soapbox I can stand upon, But God...
# 173   Treat me beneath this clear night sky, And I ...
# 174   So, so you think you can tell, Heaven from He...
# 175   Today was gonna be the day, That they're gonn...
# 176   Well my friend it seems we've come too far to...
# 177   Now I'm in town, break it down, thinking of m...
# 178   Now I'm in town break it down thinking of mak...
# 179   Well I walked from my house to yours, In a wa...
#
# [180 rows x 3 columns]

# %%
def get_lines(df):
    corpus=[]
    for index , row in df['Lyrics'].iteritems():
        row=str(row).lower()
        for words in row.split(','):
            new_words = re.findall(r"\b[a-z']+\b", unidecode(words))
            corpus= corpus+ new_words
    return corpus

# %%
all_lines=get_lines(data)

# %%
SEQ_LENGTH = 50 + 1
sequences = list()

for i in range(SEQ_LENGTH, len(all_lines)):
    seq = all_lines[i - SEQ_LENGTH: i]
    sequences.append(seq)

print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 62380

# %%
corpus= set(all_lines)
word_to_index = {w: i for i, w in enumerate(corpus)}
index_to_word = {i: w for w, i in word_to_index.items()}
word_indices = [word_to_index[word] for word in corpus]
vocab_size = len(corpus)
print('Vocabulary size: {}'.format(len(corpus)))
# Out:
# Vocabulary size: 3043

# %%
def get_tokenized_lines(lines, seq_len):
    tokenized = np.zeros((len(lines), seq_len))
    
    for r, line in enumerate(lines):
        for c, word in enumerate(line):
            tokenized[r, c] = word_to_index[word]

    return tokenized

# %%
tokenized_seq = get_tokenized_lines(sequences, SEQ_LENGTH)
tokenized_seq
# Out:
# array([[ 421.,  421.,  421., ..., 1588.,  389.,  936.],
#        [ 421.,  421.,  421., ...,  389.,  936.,  192.],
#        [ 421.,  421.,  421., ...,  936.,  192.,  907.],
#        ...,
#        [ 293.,  940., 2052., ...,   91., 2464., 1789.],
#        [ 940., 2052., 2483., ..., 2464., 1789.,  474.],
#        [2052., 2483., 1056., ..., 1789.,  474., 2975.]])

# %%
tokenized_seq[:,:-1]
# Out:
# array([[ 421.,  421.,  421., ...,  431., 1588.,  389.],
#        [ 421.,  421.,  421., ..., 1588.,  389.,  936.],
#        [ 421.,  421.,  421., ...,  389.,  936.,  192.],
#        ...,
#        [ 293.,  940., 2052., ...,  342.,   91., 2464.],
#        [ 940., 2052., 2483., ...,   91., 2464., 1789.],
#        [2052., 2483., 1056., ..., 2464., 1789.,  474.]])

# %%
tokenized_seq[:,-1]
# Out:
# array([ 936.,  192.,  907., ..., 1789.,  474., 2975.])

# %%
from keras.utils import to_categorical

X, y = tokenized_seq[:, :-1], tokenized_seq[:, -1]
y = to_categorical(y, num_classes=vocab_size)
seq_length = len(X[0])

# %%
print("X_shape", X.shape)
print("y_shape", y.shape)
# Out:
# X_shape (62380, 50)
# y_shape (62380, 3043)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding

model = Sequential()
model.add(Embedding(vocab_size, 50, input_length=seq_length))
model.add(LSTM(100, return_sequences=True))
model.add(LSTM(100))
model.add(Dense(100, activation='relu'))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, y, batch_size=128, epochs=50)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 50, 50)            152150
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50, 100)           60400
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 3043)              307343
# =================================================================
# Total params: 610,393
# Trainable params: 610,393
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 62380/62380 [==============================] - 72s 1ms/step - loss: 6.0910 - acc: 0.0400
# Epoch 2/50
# 62380/62380 [==============================] - 70s 1ms/step - loss: 5.6692 - acc: 0.0511
# Epoch 3/50
# 62380/62380 [==============================] - 69s 1ms/step - loss: 5.3708 - acc: 0.0755
# Epoch 4/50
# 62380/62380 [==============================] - 69s 1ms/step - loss: 5.1183 - acc: 0.0978
# Epoch 5/50
# 62380/62380 [==============================] - 69s 1ms/step - loss: 4.9048 - acc: 0.1179
# Epoch 6/50
# 62380/62380 [==============================] - 69s 1ms/step - loss: 4.7058 - acc: 0.1386
# Epoch 7/50
# 62380/62380 [==============================] - 69s 1ms/step - loss: 4.5220 - acc: 0.1541
# Epoch 8/50
# 62380/62380 [==============================] - 69s 1ms/step - loss: 4.3539 - acc: 0.1705
# Epoch 9/50
# 62380/62380 [==============================] - 68s 1ms/step - loss: 4.1980 - acc: 0.1878
# Epoch 10/50
# 62380/62380 [==============================] - 80s 1ms/step - loss: 1.6386 - acc: 0.6276
# Epoch 40/50
# 62380/62380 [==============================] - 75s 1ms/step - loss: 1.5966 - acc: 0.6361
# Epoch 41/50
# 62380/62380 [==============================] - 72s 1ms/step - loss: 1.5540 - acc: 0.6462
# Epoch 42/50
# 62380/62380 [==============================] - 71s 1ms/step - loss: 1.5127 - acc: 0.6558
# Epoch 43/50
# 62380/62380 [==============================] - 71s 1ms/step - loss: 1.4718 - acc: 0.6638
# Epoch 44/50
# 62380/62380 [==============================] - 72s 1ms/step - loss: 1.4346 - acc: 0.6722
# Epoch 45/50
# 62380/62380 [==============================] - 76s 1ms/step - loss: 1.3951 - acc: 0.6805
# Epoch 46/50
# 62380/62380 [==============================] - 76s 1ms/step - loss: 1.3609 - acc: 0.6871
# Epoch 47/50
# 62380/62380 [==============================] - 76s 1ms/step - loss: 1.3243 - acc: 0.6947
# Epoch 48/50
# 62380/62380 [==============================] - 76s 1ms/step - loss: 1.3015 - acc: 0.7011
# Epoch 49/50
# 62380/62380 [==============================] - 77s 1ms/step - loss: 1.2586 - acc: 0.7113
# Epoch 50/50
# 62380/62380 [==============================] - 77s 1ms/step - loss: 1.2284 - acc: 0.7160

# %%
model.save('model.h5')

# %%
from keras.models import load_model
model=load_model('model.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-7ca3e7951b4e> in <module>()
#       1 from keras.models import load_model
# ----> 2 model=load_model('model.h5')
#
# /usr/local/lib/python3.5/dist-packages/keras/models.py in load_model(filepath, custom_objects, compile)
#     256         optimizer_config = training_config['optimizer_config']
#     257         optimizer = optimizers.deserialize(optimizer_config,
# --> 258                                            custom_objects=custom_objects)
#     259
#     260         # Recover loss functions and metrics.
#
# /usr/local/lib/python3.5/dist-packages/keras/optimizers.py in deserialize(config, custom_objects)
#     687                                     module_objects=all_classes,
#     688                                     custom_objects=custom_objects,
# --> 689                                     printable_module_name='optimizer')
#     690
#     691
#
# /usr/local/lib/python3.5/dist-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     140                                                            list(custom_objects.items())))
#     141             with CustomObjectScope(custom_objects):
# --> 142                 return cls.from_config(config['config'])
#     143         else:
#     144             # Then `cls` may be a function returning a class.
#
# /usr/local/lib/python3.5/dist-packages/keras/optimizers.py in from_config(cls, config)
#     125     @classmethod
#     126     def from_config(cls, config):
# --> 127         return cls(**config)
#     128
#     129
#
# /usr/local/lib/python3.5/dist-packages/keras/optimizers.py in __init__(self, lr, beta_1, beta_2, epsilon, decay, **kwargs)
#     401     def __init__(self, lr=0.001, beta_1=0.9, beta_2=0.999,
#     402                  epsilon=1e-8, decay=0., **kwargs):
# --> 403         super(Adam, self).__init__(**kwargs)
#     404         with K.name_scope(self.__class__.__name__):
#     405             self.iterations = K.variable(0, dtype='int64', name='iterations')
#
# /usr/local/lib/python3.5/dist-packages/keras/optimizers.py in __init__(self, **kwargs)
#      61             if k not in allowed_kwargs:
#      62                 raise TypeError('Unexpected keyword argument '
# ---> 63                                 'passed to optimizer: ' + str(k))
#      64         self.__dict__.update(kwargs)
#      65         self.updates = []
#
# TypeError: Unexpected keyword argument passed to optimizer: amsgrad

# %%
model
